# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn


import warnings
warnings.filterwarnings('ignore')
from math import nan

# %%
num = pd.read_csv("numeros.csv")
num.head()
# Out:
#            Fecha    CO    NO   NO2   NOx   O3  PM25   PM10    PRS  RAINF  \
# 0       1/1/2017  2.47  16.0  15.1  31.1  6.0   NaN  143.0  709.2    0.0
# 1  1/1/2017 1:00  2.18   8.9  11.7  20.6  5.0   NaN  183.0  708.9    0.0
# 2  1/1/2017 2:00  1.77   2.0   8.6  10.5  6.0   NaN  142.0  708.5    0.0
# 3  1/1/2017 3:00  1.93   7.2  10.0  17.2  7.0   NaN  101.0  708.2    0.0
# 4  1/1/2017 4:00  1.70   2.1   8.6  10.7  7.0   NaN   85.0  707.9    0.0
#
#      RH  SO2     SR   TOUT     WD   WS
# 0  64.0  NaN  0.004  19.46  300.0  3.0
# 1  66.0  NaN  0.004  18.92  226.0  2.0
# 2  56.0  NaN  0.004  20.42  246.0  2.6
# 3  52.0  NaN  0.004  21.21  152.0  5.4
# 4  54.0  NaN  0.004  20.47  232.0  3.6

# %%
num["Fecha"] = pd.to_datetime(num["Fecha"])
num["day"] = num["Fecha"].dt.strftime("%Y-%m-%d")
num["hour"] = num["Fecha"].dt.strftime("%H:%M:%S")
num
# Out:
#                     Fecha    CO    NO   NO2   NOx   O3  PM25   PM10    PRS  \
# 0     2017-01-01 00:00:00  2.47  16.0  15.1  31.1  6.0   NaN  143.0  709.2
# 1     2017-01-01 01:00:00  2.18   8.9  11.7  20.6  5.0   NaN  183.0  708.9
# 2     2017-01-01 02:00:00  1.77   2.0   8.6  10.5  6.0   NaN  142.0  708.5
# 3     2017-01-01 03:00:00  1.93   7.2  10.0  17.2  7.0   NaN  101.0  708.2
# 4     2017-01-01 04:00:00  1.70   2.1   8.6  10.7  7.0   NaN   85.0  707.9
# ...                   ...   ...   ...   ...   ...  ...   ...    ...    ...
# 39390 2017-02-02 20:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 39391 2017-02-09 18:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 39392 2017-02-10 10:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 39393 2017-02-16 18:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 39394 2017-01-12 19:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
#
#        RAINF    RH  SO2     SR   TOUT     WD   WS         day      hour
# 0        0.0  64.0  NaN  0.004  19.46  300.0  3.0  2017-01-01  00:00:00
# 1        0.0  66.0  NaN  0.004  18.92  226.0  2.0  2017-01-01  01:00:00
# 2        0.0  56.0  NaN  0.004  20.42  246.0  2.6  2017-01-01  02:00:00
# 3        0.0  52.0  NaN  0.004  21.21  152.0  5.4  2017-01-01  03:00:00
# 4        0.0  54.0  NaN  0.004  20.47  232.0  3.6  2017-01-01  04:00:00
# ...      ...   ...  ...    ...    ...    ...  ...         ...       ...
# 39390    0.0   NaN  NaN    NaN    NaN    NaN  NaN  2017-02-02  20:00:00
# 39391    0.0   NaN  NaN    NaN    NaN    NaN  NaN  2017-02-09  18:00:00
# 39392    0.0   NaN  NaN    NaN    NaN    NaN  NaN  2017-02-10  10:00:00
# 39393    0.0   NaN  NaN    NaN    NaN    NaN  NaN  2017-02-16  18:00:00
# 39394    NaN   NaN  NaN    NaN    NaN    NaN  NaN  2017-01-12  19:00:00
#
# [39395 rows x 18 columns]

# %%
import copy 
new_df = copy.deepcopy(num)

# %%
new_df = new_df.drop_duplicates(subset=['WD','day'], keep='first')
# Out:
#                     Fecha    CO    NO   NO2   NOx   O3  PM25   PM10    PRS  \
# 0     2017-01-01 00:00:00  2.47  16.0  15.1  31.1  6.0   NaN  143.0  709.2
# 1     2017-01-01 01:00:00  2.18   8.9  11.7  20.6  5.0   NaN  183.0  708.9
# 2     2017-01-01 02:00:00  1.77   2.0   8.6  10.5  6.0   NaN  142.0  708.5
# 3     2017-01-01 03:00:00  1.93   7.2  10.0  17.2  7.0   NaN  101.0  708.2
# 4     2017-01-01 04:00:00  1.70   2.1   8.6  10.7  7.0   NaN   85.0  707.9
# ...                   ...   ...   ...   ...   ...  ...   ...    ...    ...
# 39388 2017-02-01 11:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 39389 2017-02-02 18:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 39391 2017-02-09 18:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 39392 2017-02-10 10:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 39393 2017-02-16 18:00:00   NaN   NaN   NaN   NaN  NaN   NaN    NaN    NaN
#
#        RAINF    RH  SO2     SR   TOUT     WD   WS         day      hour  \
# 0        0.0  64.0  NaN  0.004  19.46  300.0  3.0  2017-01-01  00:00:00
# 1        0.0  66.0  NaN  0.004  18.92  226.0  2.0  2017-01-01  01:00:00
# 2        0.0  56.0  NaN  0.004  20.42  246.0  2.6  2017-01-01  02:00:00
# 3        0.0  52.0  NaN  0.004  21.21  152.0  5.4  2017-01-01  03:00:00
# 4        0.0  54.0  NaN  0.004  20.47  232.0  3.6  2017-01-01  04:00:00
# ...      ...   ...  ...    ...    ...    ...  ...         ...       ...
# 39388    0.0   NaN  NaN    NaN    NaN   25.0  NaN  2017-02-01  11:00:00
# 39389    0.0   NaN  NaN    NaN    NaN    NaN  NaN  2017-02-02  18:00:00
# 39391    0.0   NaN  NaN    NaN    NaN    NaN  NaN  2017-02-09  18:00:00
# 39392    0.0   NaN  NaN    NaN    NaN    NaN  NaN  2017-02-10  10:00:00
# 39393    0.0   NaN  NaN    NaN    NaN    NaN  NaN  2017-02-16  18:00:00
#
#        Dirección_Viento
# 0                   7.0
# 1                   6.0
# 2                   6.0
# 3                   4.0
# 4                   6.0
# ...                 ...
# 39388               1.0
# 39389               NaN
# 39391               NaN
# 39392               NaN
# 39393               NaN
#
# [35518 rows x 19 columns]

# %% [markdown]
# # Diccionario de valores de dirección del viento:

# %% [markdown]
# 1: Norte 2: Noroeste 3: Oeste 4: Suroeste 5: Sur 6: Sureste 7: Este 8: Noreste

# %%
new_df.loc[num.WD <= 45,'Dirección_Viento']= 1
new_df.loc[(num.WD > 45) & (num.WD <= 90),'Dirección_Viento'] = 2  
new_df.loc[(num.WD > 90) & (num.WD <= 135),'Dirección_Viento'] = 3
new_df.loc[(num.WD > 135) & (num.WD <= 180),'Dirección_Viento'] = 4 
new_df.loc[(num.WD > 180) & (num.WD <= 225),'Dirección_Viento'] = 5
new_df.loc[(num.WD > 225) & (num.WD <= 270),'Dirección_Viento'] = 6
new_df.loc[(num.WD > 270) & (num.WD <= 315),'Dirección_Viento'] = 7
new_df.loc[num.WD > 315,'Dirección_Viento']= 8

# %%
new_df.tail(15)
# Out:
#                     Fecha  CO  NO  NO2  NOx  O3  PM25  PM10    PRS  RAINF  \
# 39380 2018-04-26 06:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN  712.3    0.0
# 39381 2018-04-26 07:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN  712.8    0.0
# 39382 2018-04-26 08:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN  713.2    0.0
# 39383 2017-01-05 18:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39384 2017-01-12 18:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39385 2017-01-19 18:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39386 2017-01-26 18:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39387 2017-01-26 20:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39388 2017-02-01 11:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39389 2017-02-02 18:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39390 2017-02-02 20:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39391 2017-02-09 18:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39392 2017-02-10 10:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39393 2017-02-16 18:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    0.0
# 39394 2017-01-12 19:00:00 NaN NaN  NaN  NaN NaN   NaN   NaN    NaN    NaN
#
#          RH  SO2     SR   TOUT    WD   WS         day      hour  \
# 39380  78.0  NaN  0.006  16.22  68.0  5.6  2018-04-26  06:00:00
# 39381  77.0  NaN  0.012  15.86  93.0  6.5  2018-04-26  07:00:00
# 39382  76.0  NaN  0.036  15.75  90.0  6.4  2018-04-26  08:00:00
# 39383   NaN  NaN    NaN    NaN   NaN  NaN  2017-01-05  18:00:00
# 39384   NaN  NaN    NaN    NaN   NaN  NaN  2017-01-12  18:00:00
# 39385   NaN  NaN    NaN    NaN   NaN  NaN  2017-01-19  18:00:00
# 39386   NaN  NaN    NaN    NaN  94.0  NaN  2017-01-26  18:00:00
# 39387   NaN  NaN    NaN    NaN   NaN  NaN  2017-01-26  20:00:00
# 39388   NaN  NaN    NaN    NaN  25.0  NaN  2017-02-01  11:00:00
# 39389   NaN  NaN    NaN    NaN   NaN  NaN  2017-02-02  18:00:00
# 39390   NaN  NaN    NaN    NaN   NaN  NaN  2017-02-02  20:00:00
# 39391   NaN  NaN    NaN    NaN   NaN  NaN  2017-02-09  18:00:00
# 39392   NaN  NaN    NaN    NaN   NaN  NaN  2017-02-10  10:00:00
# 39393   NaN  NaN    NaN    NaN   NaN  NaN  2017-02-16  18:00:00
# 39394   NaN  NaN    NaN    NaN   NaN  NaN  2017-01-12  19:00:00
#
#        Dirección_Viento
# 39380               2.0
# 39381               3.0
# 39382               2.0
# 39383               NaN
# 39384               NaN
# 39385               NaN
# 39386               3.0
# 39387               NaN
# 39388               1.0
# 39389               NaN
# 39390               NaN
# 39391               NaN
# 39392               NaN
# 39393               NaN
# 39394               NaN
